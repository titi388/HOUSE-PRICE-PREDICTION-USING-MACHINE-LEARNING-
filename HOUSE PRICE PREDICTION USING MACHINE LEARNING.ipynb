# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("train.csv")
train_df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# display the first five rows of the dataset
train_df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# randomly display seven rows
train_df.sample(7)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1274  1275          50       RL         53.0     5362   Pave   NaN      Reg
# 1323  1324          30       RL         50.0     5330   Pave   NaN      Reg
# 1092  1093          50       RL         60.0     8400   Pave   NaN      Reg
# 428    429          20       RL         64.0     6762   Pave   NaN      Reg
# 924    925          20       RL         79.0    10240   Pave   NaN      Reg
# 377    378          60       FV        102.0    11143   Pave   NaN      IR1
# 1244  1245          70       RL          NaN    11435   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 1274         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1323         HLS    AllPub  ...        0    NaN   NaN         NaN       0
# 1092         Bnk    AllPub  ...        0    NaN   NaN         NaN       0
# ...

# %%
# Check the summary of the dataframe
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# Show the dimension of the dataframe
train_df.shape
# Out:
# (1460, 81)

# %%
dim=train_df.shape
dim
# Out:
# (1460, 81)

# %%
dim[0]
# Out:
# 1460

# %%
# check for missing values
missing_value=train_df.isna().sum()
missing_value[missing_value>0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
# check for missing values
missing_value=train_df.isna().sum()
missing_value[missing_value>0]/ dim[0] * 100 # calculating percentage missing values
# Out:
# LotFrontage     17.739726
# Alley           93.767123
# MasVnrType       0.547945
# MasVnrArea       0.547945
# BsmtQual         2.534247
# BsmtCond         2.534247
# BsmtExposure     2.602740
# BsmtFinType1     2.534247
# BsmtFinType2     2.602740
# Electrical       0.068493
# FireplaceQu     47.260274
# GarageType       5.547945
# GarageYrBlt      5.547945
# GarageFinish     5.547945
# GarageQual       5.547945
# GarageCond       5.547945
# PoolQC          99.520548
# Fence           80.753425
# MiscFeature     96.301370
# dtype: float64

# %%
# check for duplicate values
train_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Data Cleaning

# %%
# drop all the columns with percentage missing values greater than 40%
train_df_d=train_df.drop(columns=["MiscFeature", "Fence", "PoolQC", "FireplaceQu", "Alley"])

# %%
missing_value=train_df_d.isna().sum()
c=missing_value[missing_value>0]
c
# Out:
# MasVnrType       8
# MasVnrArea       8
# BsmtQual        37
# BsmtCond        37
# BsmtExposure    38
# BsmtFinType1    37
# BsmtFinType2    38
# Electrical       1
# GarageType      81
# GarageYrBlt     81
# GarageFinish    81
# GarageQual      81
# GarageCond      81
# dtype: int64

# %%
c.index
# Out:
# Index(['MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinType2', 'Electrical', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond'],
#       dtype='object')

# %%
# Return dataframe for just columns with missing values
train_df_d[c.index]
# Out:
#      MasVnrType  MasVnrArea BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 0       BrkFace       196.0       Gd       TA           No          GLQ
# 1          None         0.0       Gd       TA           Gd          ALQ
# 2       BrkFace       162.0       Gd       TA           Mn          GLQ
# 3          None         0.0       TA       Gd           No          ALQ
# 4       BrkFace       350.0       Gd       TA           Av          GLQ
# ...         ...         ...      ...      ...          ...          ...
# 1455       None         0.0       Gd       TA           No          Unf
# 1456      Stone       119.0       Gd       TA           No          ALQ
# 1457       None         0.0       TA       Gd           No          GLQ
# 1458       None         0.0       TA       TA           Mn          GLQ
# 1459       None         0.0       TA       TA           No          BLQ
#
#      BsmtFinType2 Electrical GarageType  GarageYrBlt GarageFinish GarageQual  \
# ...

# %%
# Return dataframe for just columns with missing values and display numerical columns
train_df_d[c.index].select_dtypes(include=[int, float])
# Out:
#       MasVnrArea  GarageYrBlt
# 0          196.0       2003.0
# 1            0.0       1976.0
# 2          162.0       2001.0
# 3            0.0       1998.0
# 4          350.0       2000.0
# ...          ...          ...
# 1455         0.0       1999.0
# 1456       119.0       1978.0
# 1457         0.0       1941.0
# 1458         0.0       1950.0
# 1459         0.0       1965.0
#
# [1460 rows x 2 columns]

# %%
# display numerical columns
train_df_d["MasVnrArea"]
# Out:
# 0       196.0
# 1         0.0
# 2       162.0
# 3         0.0
# 4       350.0
#         ...
# 1455      0.0
# 1456    119.0
# 1457      0.0
# 1458      0.0
# 1459      0.0
# Name: MasVnrArea, Length: 1460, dtype: float64

# %%
train_df_d["MasVnrType"]
# Out:
# 0       BrkFace
# 1          None
# 2       BrkFace
# 3          None
# 4       BrkFace
#          ...
# 1455       None
# 1456      Stone
# 1457       None
# 1458       None
# 1459       None
# Name: MasVnrType, Length: 1460, dtype: object

# %%
# Fill the missing values in lotfrontage with mean
LotFrontage_mean=round(train_df_d.LotFrontage.mean() )
train_df_d.LotFrontage.fillna(LotFrontage_mean, inplace=True)

# %%
def mean_value(col):
    mean=round(train_df_d[col].mean() )
    train_df_d[col].fillna(mean, inplace=True)

# %%
test_df = pd.read_csv("test.csv")
test_df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...
